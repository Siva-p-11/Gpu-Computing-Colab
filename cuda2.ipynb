# %% [markdown]
# <a href="https://colab.research.google.com/github/Siva-p-11/Gpu-Computing-Colab/blob/main/cuda2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%writefile cuda4.cu
# #include <stdio.h>
#
# __global__ void add(int *a, int *b, int *c)
# {
#     *c = *a + *b;
# }
#
# int main()
# {
#     int a = 10, b = 20, c;
#
#     int *d_a, *d_b, *d_c;
#
#     cudaMalloc(&d_a, sizeof(int));
#     cudaMalloc(&d_b, sizeof(int));
#     cudaMalloc(&d_c, sizeof(int));
#
#     cudaMemcpy(d_a,&a,sizeof(int),cudaMemcpyHostToDevice);
#     cudaMemcpy(d_b,&b,sizeof(int),cudaMemcpyHostToDevice);
#
#     add<<<1,1>>>(d_a,d_b,d_c);
#
#     cudaMemcpy(&c,d_c,sizeof(int),cudaMemcpyDeviceToHost);
#
#     printf("Sum = %d\n",c);
#
#     cudaFree(d_a);
#     cudaFree(d_b);
#     cudaFree(d_c);
#
#     return 0;
# }
# Out:
# Overwriting cuda4.cu

# %%
# !nvcc cuda4.cu -o cuda4.cu
# Out:
# Streaming output truncated to the last 5000 lines.
# cuda4.cu:1244:50: error: extended character ̈́ is not valid at the start of an identifier
#  1244 |  D��L��L����Å�uH����[A\A]A^]��     ��H�}�H�E�    � y H�}�H��t͉���l H����[A\A]A^]�ff.�      UH��AVA��AUI��ATI��SH���n ��u/H�0
#       |                                                  ^
# cuda4.cu:1244:50: warning: `\U00000344' is not in NFC [-Wnormalized=]
# cuda4.cu:1244:53: warning: null character(s) ignored
#  1244 |  D��L��L����Å�uH����[A\A]A^]��     ��H�}�H�E�    � y H�}�H��t͉���l H����[A\A]A^]�ff.�      UH��AVA��AUI��ATI��SH���n ��u/H�0
#       |                                                     ^
# cuda4.cu:1244:67: warning: null character(s) ignored
#  1244 |  D��L��L����Å�uH����[A\A]A^]��     ��H�}�H�E�    � y H�}�H��t͉���l H����[A\A]A^]�ff.�      UH��AVA��AUI��ATI��SH���n ��u/H�0
#       |                                                                   ^
# cuda4.cu:1244:104: warning: null character(s) ignored
# ...

# %%
# !./cuda4
# Out:
# /bin/bash: line 1: ./cuda4: No such file or directory
